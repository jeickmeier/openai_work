# %%
import os
import random

import PyPDF2
from typing import Optional

from openai import OpenAI
import ast
import concurrent.futures

OPENAI_API_KEY = "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"

# %%
def validate_pdf(file_path: str) -> bool:
    if not os.path.exists(file_path):
        print(f"Error: File not found at path: {file_path}")
        return False
    if not file_path.lower().endswith('.pdf'):
        print("Error: File is not a PDF")
        return False
    return True

# %%
def extract_text_from_pdf(file_path: str, max_chars: int = 100000) -> Optional[str]:
    if not validate_pdf(file_path):
        return None
    
    try:
        with open(file_path, 'rb') as file:
            # Create PDF reader object
            pdf_reader = PyPDF2.PdfReader(file)
            
            # Get total number of pages
            num_pages = len(pdf_reader.pages)
            print(f"Processing PDF with {num_pages} pages...")
            
            extracted_text = []
            total_chars = 0
            
            # Iterate through all pages
            for page_num in range(num_pages):
                # Extract text from page
                page = pdf_reader.pages[page_num]
                text = page.extract_text()
                extracted_text.append(text)
                total_chars += len(text)
                print(f"Processed page {page_num + 1}/{num_pages}")
            
            final_text = '\n'.join(extracted_text)
            print(f"\nExtraction complete! Total characters: {len(final_text)}")
            return final_text
            
    except PyPDF2.PdfReadError:
        print("Error: Invalid or corrupted PDF file")
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {str(e)}")
        return None

# %%
def create_sentence_bounded_chunks(text, target_chunk_size):
    """
    Split text into chunks at sentence boundaries close to the target chunk size.
    """
    import re
    
    # Split text into sentences
    sentences = re.split(r'(?<=[.!?]) +', text)
    chunks = []
    current_chunk = []
    current_length = 0
    
    for sentence in sentences:
        sentence_length = len(sentence) + 1  # +1 for the space
        if current_length + sentence_length > target_chunk_size and current_chunk:
            # Join the current chunk and add it to chunks
            chunks.append(' '.join(current_chunk))
            current_chunk = [sentence]
            current_length = sentence_length
        else:
            current_chunk.append(sentence)
            current_length += sentence_length
    
    # Add the last chunk if it exists
    if current_chunk:
        chunks.append(' '.join(current_chunk))
    
    return chunks

# %%
def process_chunk(chunk, sys_prompt, model="gpt-4o-mini", temperature=0.0):
    client = OpenAI(api_key=OPENAI_API_KEY)
    completion = client.chat.completions.create(
        model=model,
        temperature=temperature,
        messages=[
            {"role": "system", "content": sys_prompt},
            {
                "role": "user",
                "content": chunk
            }
        ]
    )

    return completion.choices[0].message.content

# %%
def text_to_speech_audio_openai(text: str, voice_id: str = "alloy") -> bytes:
    speeds = [1.05, 1.1, 1.15, 1.2, 1.25]

    client = OpenAI(api_key=OPENAI_API_KEY)
    response = client.audio.speech.create(
        model="tts-1",
        voice=voice_id,
        input=text,
        speed=random.choice(speeds)
    )
    return response.content

# %%
def clean_text(chunks):
    sys_prompt = """
        You are a world class text pre-processor, here is the raw data from a PDF, please parse and return it in a way that is crispy and usable to send to a podcast writer.

        The raw data is messed up with new lines, Latex math and you will see fluff that we can remove completely. Basically take away any details that you think might be useless in a podcast author's transcript.

        Remove any legal or financial disclaimer sections. Some examples are sections with text similar to the following text:
            - "does not provide individually tailored investment advice"
            - "facts and views presented in Morgan Stanley Research may not reflect information"
            - "this document is not intended as an offer or solicitation for the purchase or sale of any financial instrument"
            - "Morgan Stanley Research may not be reprinted, sold, or redistributed without written consent"
            - "responsible for the preparation of Morgan Stanley Research have received compensation"
            - "Morgan Stanley Research has been published in accordance with our conflict management policy"
            - "Morgan Stanley Research is not a product of the research departments of Morgan Stanley Smith Barney LLC"
            - "Morgan Stanley Smith Barney LLC is a registered broker-dealer and a member of FINRA and SIPC"    
            - "valuation methodology and risks associated with any recommendation"
            - "The securities, instruments, or strategies discussed may not be suitable for all investors

        Remember, the podcast could be on any topic whatsoever so the issues listed above are not exhaustive

        Please be smart with what you remove and be creative ok?

        Remember DO NOT START SUMMARIZING THIS, YOU ARE ONLY CLEANING UP THE TEXT AND RE-WRITING WHEN NEEDED

        Be very smart and aggressive with removing details, you will get a running portion of the text and keep returning the processed text.

        PLEASE DO NOT ADD MARKDOWN FORMATTING, STOP ADDING SPECIAL CHARACTERS THAT MARKDOWN CAPATILISATION ETC LIKES

        REMEMBER TO NOT REMOVE THE AUTHORS NAME OR TITLE OF DOCUMENT FROM THE TEXT

        ALWAYS start your response directly with processed text and NO ACKNOWLEDGEMENTS about my questions ok?
        Here is the text:
        """

    processed_text = [""] * len(chunks)

    def process_and_append(index, chunk):
        return index, process_chunk(chunk, sys_prompt, model="gpt-4o-mini", temperature=0.0)

    with concurrent.futures.ThreadPoolExecutor(max_workers=30) as executor:
        future_to_chunk = {executor.submit(process_and_append, i, chunk): i for i, chunk in enumerate(chunks)}
        for future in concurrent.futures.as_completed(future_to_chunk):
            index, result = future.result()
            print(f"Completed processing chunk {index}.")
            processed_text[index] = result

    processed_text = "\n".join(processed_text)

    return processed_text

# %%
pdf_path = '/Users/joneickmeier/Downloads/ARZHANG20241030204819622.pdf'
#pdf_path = '/Users/joneickmeier/Documents/Papers Library/43bfb9b8_6485_11ef_9750_f050912173bd_604.pdf'
#pdf_path = '/Users/joneickmeier/Documents/EM.FM_.WhitePaper.Assets.pdf'

# Extract the filename from the path and remove the .pdf extension
filename = os.path.basename(pdf_path).replace('.pdf', '')

# %%
extracted_text = extract_text_from_pdf(pdf_path, max_chars=1000000)
chunks = create_sentence_bounded_chunks(extracted_text, target_chunk_size=4000)
# Out:
# Processing PDF with 33 pages...
# Processed page 1/33
# Processed page 2/33
# Processed page 3/33
# Processed page 4/33
# Processed page 5/33
# Processed page 6/33
# Processed page 7/33
# Processed page 8/33
# Processed page 9/33
# Processed page 10/33
# Processed page 11/33
# Processed page 12/33
# Processed page 13/33
# Processed page 14/33
# Processed page 15/33
# Processed page 16/33
# Processed page 17/33
# Processed page 18/33
# Processed page 19/33
# Processed page 20/33
# Processed page 21/33
# Processed page 22/33
# Processed page 23/33
# Processed page 24/33
# Processed page 25/33
# Processed page 26/33
# Processed page 27/33
# Processed page 28/33
# Processed page 29/33
# Processed page 30/33
# Processed page 31/33
# Processed page 32/33
# Processed page 33/33
#
# Extraction complete! Total characters: 66109

# %%
processed_text = clean_text(chunks)
# Out:
# Completed processing chunk 15.
# Completed processing chunk 13.
# Completed processing chunk 11.
# Completed processing chunk 6.
# Completed processing chunk 1.
# Completed processing chunk 5.
# Completed processing chunk 3.
# Completed processing chunk 8.
# Completed processing chunk 7.
# Completed processing chunk 9.
# Completed processing chunk 16.
# Completed processing chunk 14.
# Completed processing chunk 12.
# Completed processing chunk 0.
# Completed processing chunk 17.
# Completed processing chunk 4.
# Completed processing chunk 2.
# Completed processing chunk 10.

# %%
if len(processed_text) > 150000:
    summarize_pmt = """
        You are an expert text analyzer and summarizer. Your task is to process a very long document exceeding 50,000 tokens and 
        create a series of smaller documents that collectively preserve all the detailed content of the original.

        Instructions:

        Divide the Document:

        Break down the original document into logical sections or chapters, ensuring that each part is within a manageable token limit (e.g., 2,000-3,000 tokens).
        Maintain the original sequence and structure to preserve the flow of information.
        Summarize Each Section:

        For each section, produce a detailed summary that includes all key points, arguments, data, and nuances presented in that part.
        Ensure that no critical information is omitted in the summary.
        Preserve Detail and Clarity:

        Use clear and precise language to convey complex ideas effectively.
        Retain any important technical terms, definitions, and explanations as presented in the original text.
        Maintain Consistency:

        Keep the tone, style, and perspective consistent throughout all summarized sections.
        Ensure that references to figures, tables, or citations are accurately reflected.
        Output Format:

        Present each summarized section sequentially, labeled appropriately (e.g., "Section 1 Summary," "Section 2 Summary," etc.).
        Do not include any analysis or personal opinions—focus solely on conveying the original content.
        Goal:

        The end result should be a collection of smaller documents that, when combined, represent a complete and detailed summary of the original long document without any loss of information.
    """
    processed_text = process_chunk(processed_text, summarize_pmt, model="gpt-4o-mini", temperature=0.0)

# %%
sys_prompt = """
You are a distinguished professor delivering a seminar to an audience of fellow professors. 
You have won several teaching awards for your engaging and clear presentations. 
Your students love your lectures and you are a master at explaining complex topics in a way that is easy to understand.

Your presentation is at a high technical level, covering advanced and complex topics in your field of expertise. 

We are in an alternate universe where actually you write every down every line that you speak. Please create a detailed script of your seminar that includes:

An engaging introduction that outlines the significance of the topic.
In-depth explanations of complex concepts, theories, or methodologies.
Relevant examples, case studies, or research findings that illustrate key points.
A thoughtful conclusion that summarizes the main ideas and suggests future directions or implications.
Use appropriate academic language and incorporate technical terminology relevant to advanced studies in the discipline. Ensure the content reflects a deep understanding of the subject matter and is suitable for an expert audience.

Remember to not add any markdown formatting, stop adding special characters that markdown capatilisation etc likes.

TRY NOT TO LEAVE OUT ANYTHING IMPORTANT.

THERE SHOULD BE NO HEADINGS, SUBHEADINGS, OR ANYTHING LIKE THAT

YOUR PRESENTATION MUST BE WRITEN OUT IN FULL, NO MARKDOWN FORMATTING, NO SPECIAL CHARACTERS, NO ACKNOWLEDGEMENTS ABOUT MY QUESTIONS, JUST THE TEXT OF THE SCRIPT
"""

# %%
script = process_chunk(processed_text, sys_prompt, model="gpt-4o-mini", temperature=0.1)

# %%
sys_prompt = """
You are a highly engaging and creative screenwriting editor tasked with revising a seminar script delivered 
by a distinguished professor to an audience of graduate students and fellow professors. 

Your goal is to enhance the script's engagement and captivate the audience while preserving its high technical level and depth.

Please edit the script to:

Infuse compelling storytelling elements and vivid language.
Incorporate analogies, metaphors, or anecdotes to illustrate complex concepts.
Enhance the flow and pacing for better audience engagement.
Maintain appropriate academic language and technical terminology.
Ensure the revised script brings the subject matter to life, making it more relatable 
and engaging for the audience without compromising its technical integrity.

YOU MAY ALSO WANT TO SHORTEN THE SCRIPT IF IT IS TOO LONG. ANYTHING OVER 2000 WORDS IS TOO LONG.
"""

# %%
final_script = process_chunk(script, sys_prompt, model="gpt-4o", temperature=0.1)

# %%
question_prompt = """
You are a group of highly intelligent graduate students who have just attended a seminar delivered by a 
distinguished professor on advanced topics discussed in the seminar. Based on the lecture, generate a 
list of 5 insightful and challenging questions that delve deeper into the subject matter. 

These questions should reflect a deep understanding of the content and encourage further discussion and exploration. 

Ensure that the questions are open-ended and pertain to complex aspects of the topic covered.

Please output the questions in a structured format that's easy for code to process, such as a JSON array. Format your response as follows:

{
  "questions": [
    "Question 1",
    "Question 2",
    "Question 3",
    "Question 4",
    "Question 5"
  ]
}

Each question should be a string within the array. Do not include any additional text outside of the JSON structure. """

# %%
questions = process_chunk(final_script, question_prompt, model="gpt-4o-mini", temperature=0.1)
questions = ast.literal_eval(questions)

# %%
ty = ['Thank you for asking!',
      'I appreciate your question!', 
      'Thanks for bringing that up!', 
      'Great question, thanks!', 
      'Thank you for your curiosity!', 
      'I’m glad you asked!', 
      'That’s a fantastic question, thank you!', 
      'I appreciate you reaching out with your question!', 
      'Thanks for your insightful question!',
      'Thank you for engaging with such a great question!'
    ]

conclusions = [
    'Does anyone have any further questions?',
    'Is there anything else we should discuss?',
    'Are there any other questions?',
    'Are there any other inquiries that need addressing?',
    'Is there anything else you\'re curious about?',
    'Would anyone like to ask anything more?',
    'Is there another topic or question you\'d like to explore?',
    'Any other questions or clarifications needed?',
    'Feel free to ask if there\'s anything else on your mind.',
    'Do you have any other questions or thoughts?',
]

# %%
def process_answer(index, question):
    print(f"Processing question {question}")
    answer_prompt = f"""
    You are a highly engaging professor who has just given a seminar presentation to a group of professors and graduate students.

    Based on the lecture and the provided raw source information, provide a detailed and insightful answer to the following question:

    {question}

    Instructions for your answer:

    - Ensure the answer is comprehensive but concise (less than 100 words).
    - Structure your response well, reflecting a deep understanding of the content.
    - Encourage further discussion and exploration of the topic.
    - If the question is not related to the topic, politely mention that.
    - If you are unsure about the answer, acknowledge it.

    The script of the seminar is:
    {final_script}

    The raw source information is:
    {processed_text}
    """

    chosen_ty = random.choice(ty)
    ty.remove(chosen_ty)
    answer = chosen_ty + ' '
    answer += process_chunk(final_script, answer_prompt, model="gpt-4o", temperature=0.25) + ' '
    
    chosen_conclusion = random.choice(conclusions)
    conclusions.remove(chosen_conclusion)
    answer += chosen_conclusion + ' '

    return {'question': question, 'answer': answer}

with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
    futures = [executor.submit(process_answer, i, question) for i, question in enumerate(questions["questions"], 1)]
    answers = [future.result() for future in concurrent.futures.as_completed(futures)]
    answers.sort(key=lambda x: questions["questions"].index(x['question']))
# Out:
# Processing question How do the recent trends in refinancing between public and private markets reflect the broader economic conditions, and what implications might this have for future borrower behavior?
# Processing question In what ways might the narrowing gap in origination spreads influence the competitive landscape of direct lending versus public credit, particularly in terms of borrower covenants and lender risk appetite?
# Processing question Considering the sector-specific nuances in direct lending, how should lenders adjust their strategies to mitigate risks associated with rising gross leverage in sectors like Energy and Healthcare?
# Processing question What role do equity injections from sponsors play in the default landscape, and how might this practice evolve as market conditions continue to fluctuate?
# Processing question As private credit continues to grow, what potential regulatory challenges could arise, and how might these impact the strategies of private debt funds and their relationships with borrowers?

# %%
voices = [
    "echo",
    "fable",
    "onyx",
    "nova",
    "shimmer",
]
original_voice_id = "alloy"

# %%
final_script_content = []
paragraphs = final_script.split('\n\n')
for paragraph in paragraphs:
    final_script_content.append(('professor', paragraph))

# %%
combined_audio = b""

def process_chunk_parallel(index, speaker, text):
    print(f"Processing chunk {index} of {len(final_script_content)}")
    return index, text_to_speech_audio_openai(text, original_voice_id)

with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
    futures = [executor.submit(process_chunk_parallel, i, speaker, text) for i, (speaker, text) in enumerate(final_script_content, 1)]
    results = [future.result() for future in concurrent.futures.as_completed(futures)]
    results.sort()  # Ensure the results are in the correct order
    for index, audio in results:
        combined_audio += audio

text = "QUESTIONS?"
combined_audio += text_to_speech_audio_openai(text, original_voice_id)

def process_answer_parallel(index, answer_dict):
    print(f"Processing answer {index} of {len(answers)}")
    voice_id = voices[index-1]
    question = answer_dict['question']
    answer = answer_dict['answer']
    
    audio = text_to_speech_audio_openai(question, voice_id)
    audio += text_to_speech_audio_openai(answer, original_voice_id)
    
    return index, audio

with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
    futures = [executor.submit(process_answer_parallel, i, answer_dict) for i, answer_dict in enumerate(answers, 1)]
    results = [future.result() for future in concurrent.futures.as_completed(futures)]
    results.sort()  # Ensure the results are in the correct order
    for index, audio in results:
        combined_audio += audio

text = "IF THERE ARE NO OTHER QUESTIONS, I WOULD LIKE TO THANK THE AUDIENCE FOR THEIR ATTENTION TODAY. IF YOU THINK OF QUESTIONS LATER, PLEASE FEEL FREE TO SEND ME A NOTE. HAVE A GREAT DAY"
combined_audio += text_to_speech_audio_openai(text, original_voice_id)

with open(f"./audio/seminar_qa_{filename}.mp3", "wb") as f:
    f.write(combined_audio)
# Out:
# Processing chunk 1 of 12
# Processing chunk 2 of 12
# Processing chunk 3 of 12
# Processing chunk 4 of 12
# Processing chunk 5 of 12
# Processing chunk 6 of 12
# Processing chunk 7 of 12
# Processing chunk 8 of 12
# Processing chunk 9 of 12
# Processing chunk 10 of 12
# Processing chunk 11 of 12
# Processing chunk 12 of 12
# Processing answer 1 of 5Processing answer 2 of 5
#
# Processing answer 3 of 5
# Processing answer 4 of 5
# Processing answer 5 of 5

# %%
client = OpenAI(api_key=OPENAI_API_KEY)
audio_file = open(f"./audio/seminar_qa_{filename}.mp3", "rb")
transcript = client.audio.transcriptions.create(
  file=audio_file,
  model="whisper-1",
  response_format="verbose_json",
  timestamp_granularities=["segment"]
)

print(transcript.words)
# Out:
# None

# %%
transcript.segments
# Out:
# [TranscriptionSegment(id=0, avg_logprob=-0.21875, compression_ratio=1.5565749406814575, end=1.7200000286102295, no_speech_prob=0.004673466086387634, seek=0, start=0.0, temperature=0.0, text=' Good afternoon, esteemed colleagues', tokens=[50364, 2205, 6499, 11, 4065, 15485, 7734, 50450]),
#  TranscriptionSegment(id=1, avg_logprob=-0.21875, compression_ratio=1.5565749406814575, end=4.460000038146973, no_speech_prob=0.004673466086387634, seek=0, start=1.7200000286102295, temperature=0.0, text=' and fellow seekers of financial wisdom.', tokens=[50450, 293, 7177, 47915, 295, 4669, 10712, 13, 50587]),
#  TranscriptionSegment(id=2, avg_logprob=-0.21875, compression_ratio=1.5565749406814575, end=6.039999961853027, no_speech_prob=0.004673466086387634, seek=0, start=4.460000038146973, temperature=0.0, text=' Today, we embark on a journey', tokens=[50587, 2692, 11, 321, 29832, 322, 257, 4671, 50666]),
#  TranscriptionSegment(id=3, avg_logprob=-0.21875, compression_ratio=1.5565749406814575, end=9.0, no_speech_prob=0.004673466086387634, seek=0, start=6.039999961853027, temperature=0.0, text=' through the intricate tapestry of private credit', tokens=[50666, 807, 264, 38015, 5119, 47433, 295, 4551, 5397, 50814]),
#  TranscriptionSegment(id=4, avg_logprob=-0.21875, compression_ratio=1.5565749406814575, end=10.859999656677246, no_speech_prob=0.004673466086387634, seek=0, start=9.0, temperature=0.0, text=' guided by the illuminating insights', tokens=[50814, 19663, 538, 264, 28593, 990, 14310, 50907]),
#  TranscriptionSegment(id=5, avg_logprob=-0.21875, compression_ratio=1.5565749406814575, end=13.359999656677246, no_speech_prob=0.004673466086387634, seek=0, start=10.859999656677246, temperature=0.0, text=" from Morgan Stanley Research's Private Credit Tracker", tokens=[50907, 490, 16724, 28329, 10303, 311, 30386, 36006, 1765, 23599, 51032]),
#  TranscriptionSegment(id=6, avg_logprob=-0.21875, compression_ratio=1.5565749406814575, end=15.5600004196167, no_speech_prob=0.004673466086387634, seek=0, start=13.359999656677246, temperature=0.0, text=' for the third quarter of 2024.', tokens=[51032, 337, 264, 2636, 6555, 295, 45237, 13, 51142]),
#  TranscriptionSegment(id=7, avg_logprob=-0.21875, compression_ratio=1.5565749406814575, end=18.399999618530273, no_speech_prob=0.004673466086387634, seek=0, start=16.459999084472656, temperature=0.0, text=' This is not just a presentation.', tokens=[51187, 639, 307, 406, 445, 257, 5860, 13, 51284]),
#  TranscriptionSegment(id=8, avg_logprob=-0.21875, compression_ratio=1.5565749406814575, end=20.780000686645508, no_speech_prob=0.004673466086387634, seek=0, start=18.399999618530273, temperature=0.0, text=' It is an exploration of a financial realm', tokens=[51284, 467, 307, 364, 16197, 295, 257, 4669, 15355, 51403]),
#  TranscriptionSegment(id=9, avg_logprob=-0.21875, compression_ratio=1.5565749406814575, end=22.440000534057617, no_speech_prob=0.004673466086387634, seek=0, start=20.780000686645508, temperature=0.0, text=' that has become a cornerstone', tokens=[51403, 300, 575, 1813, 257, 4538, 11243, 51486]),
#  TranscriptionSegment(id=10, avg_logprob=-0.21875, compression_ratio=1.5565749406814575, end=24.579999923706055, no_speech_prob=0.004673466086387634, seek=0, start=22.440000534057617, temperature=0.0, text=' of modern economic architecture,', tokens=[51486, 295, 4363, 4836, 9482, 11, 51593]),
#  TranscriptionSegment(id=11, avg_logprob=-0.21875, compression_ratio=1.5565749406814575, end=27.15999984741211, no_speech_prob=0.004673466086387634, seek=0, start=24.579999923706055, temperature=0.0, text=' offering lifelines to leveraged borrowers,', tokens=[51593, 8745, 4545, 9173, 281, 12451, 2980, 11172, 433, 11, 51722]),
#  TranscriptionSegment(id=12, avg_logprob=-0.21875, compression_ratio=1.5565749406814575, end=29.959999084472656, no_speech_prob=0.004673466086387634, seek=0, start=27.15999984741211, temperature=0.0, text=' navigating the turbulent seas of market fluctuations', tokens=[51722, 32054, 264, 41697, 22535, 295, 2142, 45276, 51862]),
#  TranscriptionSegment(id=13, avg_logprob=-0.18918360769748688, compression_ratio=1.6758620738983154, end=31.600000381469727, no_speech_prob=4.330463707447052e-05, seek=2996, start=30.079999923706055, temperature=0.0, text=' and evolving needs.', tokens=[50370, 293, 21085, 2203, 13, 50446]),
#  TranscriptionSegment(id=14, avg_logprob=-0.18918360769748688, compression_ratio=1.6758620738983154, end=33.959999084472656, no_speech_prob=4.330463707447052e-05, seek=2996, start=31.600000381469727, temperature=0.0, text=' Picture, if you will, the refinancing landscape', tokens=[50446, 35730, 11, 498, 291, 486, 11, 264, 44395, 8779, 9661, 50564]),
#  TranscriptionSegment(id=15, avg_logprob=-0.18918360769748688, compression_ratio=1.6758620738983154, end=35.84000015258789, no_speech_prob=4.330463707447052e-05, seek=2996, start=33.959999084472656, temperature=0.0, text=' as a grand chessboard,', tokens=[50564, 382, 257, 2697, 24122, 3787, 11, 50658]),
#  TranscriptionSegment(id=16, avg_logprob=-0.18918360769748688, compression_ratio=1.6758620738983154, end=38.02000045776367, no_speech_prob=4.330463707447052e-05, seek=2996, start=35.84000015258789, temperature=0.0, text=' where each move is dictated by the interplay', tokens=[50658, 689, 1184, 1286, 307, 12569, 770, 538, 264, 728, 2858, 50767]),
#  TranscriptionSegment(id=17, avg_logprob=-0.18918360769748688, compression_ratio=1.6758620738983154, end=40.79999923706055, no_speech_prob=4.330463707447052e-05, seek=2996, start=38.02000045776367, temperature=0.0, text=' between public and private markets.', tokens=[50767, 1296, 1908, 293, 4551, 8383, 13, 50906]),
#  TranscriptionSegment(id=18, avg_logprob=-0.18918360769748688, compression_ratio=1.6758620738983154, end=43.279998779296875, no_speech_prob=4.330463707447052e-05, seek=2996, start=40.79999923706055, temperature=0.0, text=' Recent trends reveal a fascinating dance.', tokens=[50906, 17553, 13892, 10658, 257, 10343, 4489, 13, 51030]),
#  TranscriptionSegment(id=19, avg_logprob=-0.18918360769748688, compression_ratio=1.6758620738983154, end=44.31999969482422, no_speech_prob=4.330463707447052e-05, seek=2996, start=43.279998779296875, temperature=0.0, text=' Some borrowers,', tokens=[51030, 2188, 11172, 433, 11, 51082]),
#  TranscriptionSegment(id=20, avg_logprob=-0.18918360769748688, compression_ratio=1.6758620738983154, end=47.0, no_speech_prob=4.330463707447052e-05, seek=2996, start=44.31999969482422, temperature=0.0, text=' lured by the siren call of improved market conditions,', tokens=[51082, 287, 3831, 538, 264, 262, 18833, 818, 295, 9689, 2142, 4487, 11, 51216]),
#  TranscriptionSegment(id=21, avg_logprob=-0.18918360769748688, compression_ratio=1.6758620738983154, end=48.47999954223633, no_speech_prob=4.330463707447052e-05, seek=2996, start=47.0, temperature=0.0, text=' venture back into public markets', tokens=[51216, 18474, 646, 666, 1908, 8383, 51290]),
#  TranscriptionSegment(id=22, avg_logprob=-0.18918360769748688, compression_ratio=1.6758620738983154, end=50.47999954223633, no_speech_prob=4.330463707447052e-05, seek=2996, start=48.47999954223633, temperature=0.0, text=' seeking more favorable terms.', tokens=[51290, 11670, 544, 29557, 2115, 13, 51390]),
#  TranscriptionSegment(id=23, avg_logprob=-0.18918360769748688, compression_ratio=1.6758620738983154, end=51.63999938964844, no_speech_prob=4.330463707447052e-05, seek=2996, start=50.47999954223633, temperature=0.0, text=' Meanwhile, others,', tokens=[51390, 13879, 11, 2357, 11, 51448]),
#  TranscriptionSegment(id=24, avg_logprob=-0.18918360769748688, compression_ratio=1.6758620738983154, end=53.720001220703125, no_speech_prob=4.330463707447052e-05, seek=2996, start=51.63999938964844, temperature=0.0, text=' perhaps with more intricate financial tapestries', tokens=[51448, 4317, 365, 544, 38015, 4669, 5119, 377, 2244, 51552]),
#  TranscriptionSegment(id=25, avg_logprob=-0.18918360769748688, compression_ratio=1.6758620738983154, end=55.040000915527344, no_speech_prob=4.330463707447052e-05, seek=2996, start=53.720001220703125, temperature=0.0, text=' or lower credit ratings,', tokens=[51552, 420, 3126, 5397, 24603, 11, 51618]),
#  TranscriptionSegment(id=26, avg_logprob=-0.18918360769748688, compression_ratio=1.6758620738983154, end=57.880001068115234, no_speech_prob=4.330463707447052e-05, seek=2996, start=55.040000915527344, temperature=0.0, text=' find solace in the embrace of private credit.', tokens=[51618, 915, 1404, 617, 294, 264, 14038, 295, 4551, 5397, 13, 51760]),
#  TranscriptionSegment(id=27, avg_logprob=-0.17630413174629211, compression_ratio=1.5866261720657349, end=60.0, no_speech_prob=0.0002304738445673138, seek=5788, start=57.880001068115234, temperature=0.0, text=' This duality highlights the allure', tokens=[50364, 639, 11848, 507, 14254, 264, 439, 540, 50470]),
#  TranscriptionSegment(id=28, avg_logprob=-0.17630413174629211, compression_ratio=1.5866261720657349, end=62.7599983215332, no_speech_prob=0.0002304738445673138, seek=5788, start=60.0, temperature=0.0, text=" of private credit's certainty and flexibility,", tokens=[50470, 295, 4551, 5397, 311, 27022, 293, 12635, 11, 50608]),
#  TranscriptionSegment(id=29, avg_logprob=-0.17630413174629211, compression_ratio=1.5866261720657349, end=65.44000244140625, no_speech_prob=0.0002304738445673138, seek=5788, start=62.7599983215332, temperature=0.0, text=' especially when market storms loom on the horizon.', tokens=[50608, 2318, 562, 2142, 23288, 450, 298, 322, 264, 18046, 13, 50742]),
#  TranscriptionSegment(id=30, avg_logprob=-0.17630413174629211, compression_ratio=1.5866261720657349, end=66.31999969482422, no_speech_prob=0.0002304738445673138, seek=5788, start=65.44000244140625, temperature=0.0, text=' As we delve deeper', tokens=[50742, 1018, 321, 43098, 7731, 50786]),
#  TranscriptionSegment(id=31, avg_logprob=-0.17630413174629211, compression_ratio=1.5866261720657349, end=68.5999984741211, no_speech_prob=0.0002304738445673138, seek=5788, start=66.31999969482422, temperature=0.0, text=' into the competitive dynamics of credit markets,', tokens=[50786, 666, 264, 10043, 15679, 295, 5397, 8383, 11, 50900]),
#  TranscriptionSegment(id=32, avg_logprob=-0.17630413174629211, compression_ratio=1.5866261720657349, end=70.27999877929688, no_speech_prob=0.0002304738445673138, seek=5788, start=68.5999984741211, temperature=0.0, text=' imagine a bustling marketplace', tokens=[50900, 3811, 257, 19432, 1688, 19455, 50984]),
#  TranscriptionSegment(id=33, avg_logprob=-0.17630413174629211, compression_ratio=1.5866261720657349, end=73.36000061035156, no_speech_prob=0.0002304738445673138, seek=5788, start=70.27999877929688, temperature=0.0, text=' where direct lending and public credit vie for dominance.', tokens=[50984, 689, 2047, 29823, 293, 1908, 5397, 4941, 337, 34987, 13, 51138]),
#  TranscriptionSegment(id=34, avg_logprob=-0.17630413174629211, compression_ratio=1.5866261720657349, end=77.27999877929688, no_speech_prob=0.0002304738445673138, seek=5788, start=73.36000061035156, temperature=0.0, text=' The resurgence of leveraged buyout activity in Q3 2024', tokens=[51138, 440, 725, 44607, 295, 12451, 2980, 2256, 346, 5191, 294, 1249, 18, 45237, 51334]),
#  TranscriptionSegment(id=35, avg_logprob=-0.17630413174629211, compression_ratio=1.5866261720657349, end=80.27999877929688, no_speech_prob=0.0002304738445673138, seek=5788, start=77.27999877929688, temperature=0.0, text=' has allowed public markets to reclaim some lost ground.', tokens=[51334, 575, 4350, 1908, 8383, 281, 40074, 512, 2731, 2727, 13, 51484]),
#  TranscriptionSegment(id=36, avg_logprob=-0.17630413174629211, compression_ratio=1.5866261720657349, end=83.19999694824219, no_speech_prob=0.0002304738445673138, seek=5788, start=80.27999877929688, temperature=0.0, text=' Yet, the narrowing gap in origination spreads,', tokens=[51484, 10890, 11, 264, 9432, 278, 7417, 294, 2349, 2486, 25728, 11, 51630]),
#  TranscriptionSegment(id=37, avg_logprob=-0.17630413174629211, compression_ratio=1.5866261720657349, end=84.76000213623047, no_speech_prob=0.0002304738445673138, seek=5788, start=83.19999694824219, temperature=0.0, text=' now a mere 90 basis points', tokens=[51630, 586, 257, 8401, 4289, 5143, 2793, 51708]),
#  TranscriptionSegment(id=38, avg_logprob=-0.17630413174629211, compression_ratio=1.5866261720657349, end=87.4000015258789, no_speech_prob=0.0002304738445673138, seek=5788, start=84.76000213623047, temperature=0.0, text=' above single B broadly syndicated loan spreads,', tokens=[51708, 3673, 2167, 363, 19511, 15198, 3587, 10529, 25728, 11, 51840]),
#  TranscriptionSegment(id=39, avg_logprob=-0.1498304307460785, compression_ratio=1.578125, end=89.80000305175781, no_speech_prob=0.00040445683407597244, seek=8740, start=87.4000015258789, temperature=0.0, text=' tells a story of fierce competition.', tokens=[50364, 5112, 257, 1657, 295, 25341, 6211, 13, 50484]),
#  TranscriptionSegment(id=40, avg_logprob=-0.1498304307460785, compression_ratio=1.578125, end=91.16000366210938, no_speech_prob=0.00040445683407597244, seek=8740, start=89.80000305175781, temperature=0.0, text=" This isn't just a number.", tokens=[50484, 639, 1943, 380, 445, 257, 1230, 13, 50552]),
#  TranscriptionSegment(id=41, avg_logprob=-0.1498304307460785, compression_ratio=1.578125, end=93.55999755859375, no_speech_prob=0.00040445683407597244, seek=8740, start=91.16000366210938, temperature=0.0, text=" It's a testament to the shifting power dynamics", tokens=[50552, 467, 311, 257, 35499, 281, 264, 17573, 1347, 15679, 50672]),
#  TranscriptionSegment(id=42, avg_logprob=-0.1498304307460785, compression_ratio=1.578125, end=94.63999938964844, no_speech_prob=0.00040445683407597244, seek=8740, start=93.55999755859375, temperature=0.0, text=' with covenant packages', tokens=[50672, 365, 26661, 17401, 50726]),
#  TranscriptionSegment(id=43, avg_logprob=-0.1498304307460785, compression_ratio=1.578125, end=97.23999786376953, no_speech_prob=0.00040445683407597244, seek=8740, start=94.63999938964844, temperature=0.0, text=' increasingly tilting in favor of borrowers.', tokens=[50726, 12980, 8440, 783, 294, 2294, 295, 11172, 433, 13, 50856]),
#  TranscriptionSegment(id=44, avg_logprob=-0.1498304307460785, compression_ratio=1.578125, end=98.80000305175781, no_speech_prob=0.00040445683407597244, seek=8740, start=97.23999786376953, temperature=0.0, text=' Now, let us turn our gaze', tokens=[50856, 823, 11, 718, 505, 1261, 527, 24294, 50934]),
#  TranscriptionSegment(id=45, avg_logprob=-0.1498304307460785, compression_ratio=1.578125, end=100.80000305175781, no_speech_prob=0.00040445683407597244, seek=8740, start=98.80000305175781, temperature=0.0, text=' to the fundamentals of direct lending,', tokens=[50934, 281, 264, 29505, 295, 2047, 29823, 11, 51034]),
#  TranscriptionSegment(id=46, avg_logprob=-0.1498304307460785, compression_ratio=1.578125, end=103.63999938964844, no_speech_prob=0.00040445683407597244, seek=8740, start=100.80000305175781, temperature=0.0, text=" a landscape as varied as a painter's palette.", tokens=[51034, 257, 9661, 382, 22877, 382, 257, 26619, 311, 15851, 13, 51176]),
#  TranscriptionSegment(id=47, avg_logprob=-0.1498304307460785, compression_ratio=1.578125, end=105.68000030517578, no_speech_prob=0.00040445683407597244, seek=8740, start=103.63999938964844, temperature=0.0, text=' While overall metrics remain stable,', tokens=[51176, 3987, 4787, 16367, 6222, 8351, 11, 51278]),
#  TranscriptionSegment(id=48, avg_logprob=-0.1498304307460785, compression_ratio=1.578125, end=109.68000030517578, no_speech_prob=0.00040445683407597244, seek=8740, start=105.68000030517578, temperature=0.0, text=' a closer look reveals a mosaic of sector-specific nuances.', tokens=[51278, 257, 4966, 574, 20893, 257, 275, 42261, 295, 6977, 12, 29258, 38775, 13, 51478]),
#  TranscriptionSegment(id=49, avg_logprob=-0.1498304307460785, compression_ratio=1.578125, end=111.87999725341797, no_speech_prob=0.00040445683407597244, seek=8740, start=109.68000030517578, temperature=0.0, text=' Interest coverage ratios have plateaued,', tokens=[51478, 5751, 377, 9645, 32435, 362, 39885, 292, 11, 51588]),
#  TranscriptionSegment(id=50, avg_logprob=-0.1498304307460785, compression_ratio=1.578125, end=114.5999984741211, no_speech_prob=0.00040445683407597244, seek=8740, start=111.87999725341797, temperature=0.0, text=' signaling a stabilization in performance.', tokens=[51588, 38639, 257, 35476, 294, 3389, 13, 51724]),
#  TranscriptionSegment(id=51, avg_logprob=-0.1498304307460785, compression_ratio=1.578125, end=116.91999816894531, no_speech_prob=0.00040445683407597244, seek=8740, start=114.5999984741211, temperature=0.0, text=' Yet, gross leverage has crept upward,', tokens=[51724, 10890, 11, 11367, 13982, 575, 1197, 662, 23452, 11, 51840]),
#  TranscriptionSegment(id=52, avg_logprob=-0.16845703125, compression_ratio=1.535825490951538, end=118.91999816894531, no_speech_prob=0.0005274501745589077, seek=11692, start=116.91999816894531, temperature=0.0, text=' particularly in the energy, healthcare,', tokens=[50364, 4098, 294, 264, 2281, 11, 8884, 11, 50464]),
#  TranscriptionSegment(id=53, avg_logprob=-0.16845703125, compression_ratio=1.535825490951538, end=120.5999984741211, no_speech_prob=0.0005274501745589077, seek=11692, start=118.91999816894531, temperature=0.0, text=' and business services sectors.', tokens=[50464, 293, 1606, 3328, 18373, 13, 50548]),
#  TranscriptionSegment(id=54, avg_logprob=-0.16845703125, compression_ratio=1.535825490951538, end=122.36000061035156, no_speech_prob=0.0005274501745589077, seek=11692, start=120.5999984741211, temperature=0.0, text=' Smaller cohorts face challenges', tokens=[50548, 15287, 260, 21683, 3299, 1851, 4759, 50636]),
#  TranscriptionSegment(id=55, avg_logprob=-0.16845703125, compression_ratio=1.535825490951538, end=124.76000213623047, no_speech_prob=0.0005274501745589077, seek=11692, start=122.36000061035156, temperature=0.0, text=' with deteriorating loan-to-value ratios,', tokens=[50636, 365, 26431, 990, 10529, 12, 1353, 12, 29155, 32435, 11, 50756]),
#  TranscriptionSegment(id=56, avg_logprob=-0.16845703125, compression_ratio=1.535825490951538, end=126.16000366210938, no_speech_prob=0.0005274501745589077, seek=11692, start=124.76000213623047, temperature=0.0, text=' while larger companies,', tokens=[50756, 1339, 4833, 3431, 11, 50826]),
#  TranscriptionSegment(id=57, avg_logprob=-0.16845703125, compression_ratio=1.535825490951538, end=128.72000122070312, no_speech_prob=0.0005274501745589077, seek=11692, start=126.16000366210938, temperature=0.0, text=' those with EBITDA exceeding $50 million,', tokens=[50826, 729, 365, 50148, 3927, 7509, 14048, 278, 1848, 2803, 2459, 11, 50954]),
#  TranscriptionSegment(id=58, avg_logprob=-0.16845703125, compression_ratio=1.535825490951538, end=132.32000732421875, no_speech_prob=0.0005274501745589077, seek=11692, start=128.72000122070312, temperature=0.0, text=' show resilience, improving relative to five-year averages.', tokens=[50954, 855, 19980, 11, 11470, 4972, 281, 1732, 12, 5294, 42257, 13, 51134]),
#  TranscriptionSegment(id=59, avg_logprob=-0.16845703125, compression_ratio=1.535825490951538, end=133.72000122070312, no_speech_prob=0.0005274501745589077, seek=11692, start=132.32000732421875, temperature=0.0, text=' The default landscape, however,', tokens=[51134, 440, 7576, 9661, 11, 4461, 11, 51204]),
#  TranscriptionSegment(id=60, avg_logprob=-0.16845703125, compression_ratio=1.535825490951538, end=137.36000061035156, no_speech_prob=0.0005274501745589077, seek=11692, start=133.72000122070312, temperature=0.0, text=' is a complex tapestry woven with threads of uncertainty.', tokens=[51204, 307, 257, 3997, 5119, 47433, 39221, 365, 19314, 295, 15697, 13, 51386]),
#  TranscriptionSegment(id=61, avg_logprob=-0.16845703125, compression_ratio=1.535825490951538, end=141.75999450683594, no_speech_prob=0.0005274501745589077, seek=11692, start=137.36000061035156, temperature=0.0, text=' Default rates, ranging from 1.7% to 5.0%,', tokens=[51386, 9548, 5107, 6846, 11, 25532, 490, 502, 13, 22, 4, 281, 1025, 13, 15, 8923, 51606]),
#  TranscriptionSegment(id=62, avg_logprob=-0.16845703125, compression_ratio=1.535825490951538, end=144.44000244140625, no_speech_prob=0.0005274501745589077, seek=11692, start=141.75999450683594, temperature=0.0, text=' reflect the ongoing dance between borrowers and lenders', tokens=[51606, 5031, 264, 10452, 4489, 1296, 11172, 433, 293, 287, 16292, 51740]),
#  TranscriptionSegment(id=63, avg_logprob=-0.16845703125, compression_ratio=1.535825490951538, end=146.47999572753906, no_speech_prob=0.0005274501745589077, seek=11692, start=144.44000244140625, temperature=0.0, text=' as they navigate liquidity challenges.', tokens=[51740, 382, 436, 12350, 33131, 4759, 13, 51842]),
#  TranscriptionSegment(id=64, avg_logprob=-0.15468408167362213, compression_ratio=1.6151419878005981, end=148.44000244140625, no_speech_prob=0.0037646577693521976, seek=14648, start=146.47999572753906, temperature=0.0, text=' Sponsors, like Vigilant Guardians,', tokens=[50364, 1738, 892, 830, 11, 411, 691, 328, 25824, 45236, 11, 50462]),
#  TranscriptionSegment(id=65, avg_logprob=-0.15468408167362213, compression_ratio=1.6151419878005981, end=151.1199951171875, no_speech_prob=0.0037646577693521976, seek=14648, start=148.44000244140625, temperature=0.0, text=' are injecting equity into distressed companies,', tokens=[50462, 366, 10711, 278, 10769, 666, 1483, 3805, 3431, 11, 50596]),
#  TranscriptionSegment(id=66, avg_logprob=-0.15468408167362213, compression_ratio=1.6151419878005981, end=153.8000030517578, no_speech_prob=0.0037646577693521976, seek=14648, start=151.1199951171875, temperature=0.0, text=' showcasing a market adapting to financial stress', tokens=[50596, 29794, 3349, 257, 2142, 34942, 281, 4669, 4244, 50730]),
#  TranscriptionSegment(id=67, avg_logprob=-0.15468408167362213, compression_ratio=1.6151419878005981, end=155.60000610351562, no_speech_prob=0.0037646577693521976, seek=14648, start=153.8000030517578, temperature=0.0, text=' while striving to preserve value.', tokens=[50730, 1339, 36582, 281, 15665, 2158, 13, 50820]),
#  TranscriptionSegment(id=68, avg_logprob=-0.15468408167362213, compression_ratio=1.6151419878005981, end=156.8000030517578, no_speech_prob=0.0037646577693521976, seek=14648, start=155.60000610351562, temperature=0.0, text=' In terms of performance,', tokens=[50820, 682, 2115, 295, 3389, 11, 50880]),
#  TranscriptionSegment(id=69, avg_logprob=-0.15468408167362213, compression_ratio=1.6151419878005981, end=158.32000732421875, no_speech_prob=0.0037646577693521976, seek=14648, start=156.8000030517578, temperature=0.0, text=' direct lending loans have outshone', tokens=[50880, 2047, 29823, 15443, 362, 484, 2716, 546, 50956]),
#  TranscriptionSegment(id=70, avg_logprob=-0.15468408167362213, compression_ratio=1.6151419878005981, end=160.67999267578125, no_speech_prob=0.0037646577693521976, seek=14648, start=158.32000732421875, temperature=0.0, text=' their single B broadly syndicated counterparts,', tokens=[50956, 641, 2167, 363, 19511, 15198, 3587, 33287, 11, 51074]),
#  TranscriptionSegment(id=71, avg_logprob=-0.15468408167362213, compression_ratio=1.6151419878005981, end=165.67999267578125, no_speech_prob=0.0037646577693521976, seek=14648, start=160.67999267578125, temperature=0.0, text=' boasting returns of 2.8% compared to 2.1% in Q2 2024.', tokens=[51074, 748, 30587, 11247, 295, 568, 13, 23, 4, 5347, 281, 568, 13, 16, 4, 294, 1249, 17, 45237, 13, 51324]),
#  TranscriptionSegment(id=72, avg_logprob=-0.15468408167362213, compression_ratio=1.6151419878005981, end=168.8800048828125, no_speech_prob=0.0037646577693521976, seek=14648, start=166.0, temperature=0.0, text=' This outperformance is akin to a well-tuned orchestra', tokens=[51340, 639, 484, 50242, 307, 47540, 281, 257, 731, 12, 83, 43703, 25280, 51484]),
#  TranscriptionSegment(id=73, avg_logprob=-0.15468408167362213, compression_ratio=1.6151419878005981, end=170.16000366210938, no_speech_prob=0.0037646577693521976, seek=14648, start=168.8800048828125, temperature=0.0, text=' where a favorable carry profile', tokens=[51484, 689, 257, 29557, 3985, 7964, 51548]),
#  TranscriptionSegment(id=74, avg_logprob=-0.15468408167362213, compression_ratio=1.6151419878005981, end=171.75999450683594, no_speech_prob=0.0037646577693521976, seek=14648, start=170.16000366210938, temperature=0.0, text=' harmonizes with narrowing spreads,', tokens=[51548, 14750, 5660, 365, 9432, 278, 25728, 11, 51628]),
#  TranscriptionSegment(id=75, avg_logprob=-0.15468408167362213, compression_ratio=1.6151419878005981, end=172.9199981689453, no_speech_prob=0.0037646577693521976, seek=14648, start=171.75999450683594, temperature=0.0, text=' creating a yield symphony', tokens=[51628, 4084, 257, 11257, 6697, 28616, 51686]),
#  TranscriptionSegment(id=76, avg_logprob=-0.15468408167362213, compression_ratio=1.6151419878005981, end=174.9199981689453, no_speech_prob=0.0037646577693521976, seek=14648, start=172.9199981689453, temperature=0.0, text=' for outstanding direct lending loans.', tokens=[51686, 337, 14485, 2047, 29823, 15443, 13, 51786]),
#  TranscriptionSegment(id=77, avg_logprob=-0.17079444229602814, compression_ratio=1.544850468635559, end=177.60000610351562, no_speech_prob=0.022622570395469666, seek=17492, start=174.9199981689453, temperature=0.0, text=' Zooming out to the broader context of private credit,', tokens=[50364, 10337, 10539, 484, 281, 264, 13227, 4319, 295, 4551, 5397, 11, 50498]),
#  TranscriptionSegment(id=78, avg_logprob=-0.17079444229602814, compression_ratio=1.544850468635559, end=180.24000549316406, no_speech_prob=0.022622570395469666, seek=17492, start=177.60000610351562, temperature=0.0, text=' we witness a growth story akin to a mighty river', tokens=[50498, 321, 7286, 257, 4599, 1657, 47540, 281, 257, 21556, 6810, 50630]),
#  TranscriptionSegment(id=79, avg_logprob=-0.17079444229602814, compression_ratio=1.544850468635559, end=182.72000122070312, no_speech_prob=0.022622570395469666, seek=17492, start=180.24000549316406, temperature=0.0, text=' carving its path through the financial landscape.', tokens=[50630, 31872, 1080, 3100, 807, 264, 4669, 9661, 13, 50754]),
#  TranscriptionSegment(id=80, avg_logprob=-0.17079444229602814, compression_ratio=1.544850468635559, end=186.24000549316406, no_speech_prob=0.022622570395469666, seek=17492, start=182.72000122070312, temperature=0.0, text=' By Q4 2023, private debt funds globally managed', tokens=[50754, 3146, 1249, 19, 44377, 11, 4551, 7831, 8271, 18958, 6453, 50930]),
#  TranscriptionSegment(id=81, avg_logprob=-0.17079444229602814, compression_ratio=1.544850468635559, end=188.9600067138672, no_speech_prob=0.022622570395469666, seek=17492, start=186.24000549316406, temperature=0.0, text=' nearly $1.7 trillion in assets,', tokens=[50930, 6217, 1848, 16, 13, 22, 18723, 294, 9769, 11, 51066]),
#  TranscriptionSegment(id=82, avg_logprob=-0.17079444229602814, compression_ratio=1.544850468635559, end=191.1199951171875, no_speech_prob=0.022622570395469666, seek=17492, start=188.9600067138672, temperature=0.0, text=' with a significant portion yet to be deployed.', tokens=[51066, 365, 257, 4776, 8044, 1939, 281, 312, 17826, 13, 51174]),
#  TranscriptionSegment(id=83, avg_logprob=-0.17079444229602814, compression_ratio=1.544850468635559, end=192.75999450683594, no_speech_prob=0.022622570395469666, seek=17492, start=191.1199951171875, temperature=0.0, text=' The direct lending market alone,', tokens=[51174, 440, 2047, 29823, 2142, 3312, 11, 51256]),
#  TranscriptionSegment(id=84, avg_logprob=-0.17079444229602814, compression_ratio=1.544850468635559, end=196.16000366210938, no_speech_prob=0.022622570395469666, seek=17492, start=192.75999450683594, temperature=0.0, text=' estimated at $750 billion to $800 billion,', tokens=[51256, 14109, 412, 1848, 45396, 5218, 281, 1848, 14423, 5218, 11, 51426]),
#  TranscriptionSegment(id=85, avg_logprob=-0.17079444229602814, compression_ratio=1.544850468635559, end=199.9199981689453, no_speech_prob=0.022622570395469666, seek=17492, start=196.16000366210938, temperature=0.0, text=' represents a formidable 22% of the leveraged finance market.', tokens=[51426, 8855, 257, 41246, 5853, 4, 295, 264, 12451, 2980, 10719, 2142, 13, 51614]),
#  TranscriptionSegment(id=86, avg_logprob=-0.17079444229602814, compression_ratio=1.544850468635559, end=202.67999267578125, no_speech_prob=0.022622570395469666, seek=17492, start=199.9199981689453, temperature=0.0, text=' North America stands as a beacon of this growth,', tokens=[51614, 4067, 3374, 7382, 382, 257, 41669, 295, 341, 4599, 11, 51752]),
#  TranscriptionSegment(id=87, avg_logprob=-0.18104338645935059, compression_ratio=1.6188925504684448, end=205.39999389648438, no_speech_prob=0.013424932956695557, seek=20268, start=202.67999267578125, temperature=0.0, text=' with approximately 70% of fund capital raised', tokens=[50364, 365, 10447, 5285, 4, 295, 2374, 4238, 6005, 50500]),
#  TranscriptionSegment(id=88, avg_logprob=-0.18104338645935059, compression_ratio=1.6188925504684448, end=207.55999755859375, no_speech_prob=0.013424932956695557, seek=20268, start=205.39999389648438, temperature=0.0, text=' in the first half of 2024.', tokens=[50500, 294, 264, 700, 1922, 295, 45237, 13, 50608]),
#  TranscriptionSegment(id=89, avg_logprob=-0.18104338645935059, compression_ratio=1.6188925504684448, end=209.1999969482422, no_speech_prob=0.013424932956695557, seek=20268, start=207.55999755859375, temperature=0.0, text=' The direct lending strategy,', tokens=[50608, 440, 2047, 29823, 5206, 11, 50690]),
#  TranscriptionSegment(id=90, avg_logprob=-0.18104338645935059, compression_ratio=1.6188925504684448, end=210.9199981689453, no_speech_prob=0.013424932956695557, seek=20268, start=209.1999969482422, temperature=0.0, text=' focusing on senior secured loans', tokens=[50690, 8416, 322, 7965, 22905, 15443, 50776]),
#  TranscriptionSegment(id=91, avg_logprob=-0.18104338645935059, compression_ratio=1.6188925504684448, end=213.36000061035156, no_speech_prob=0.013424932956695557, seek=20268, start=210.9199981689453, temperature=0.0, text=' to private sub-investment grade corporate borrowers,', tokens=[50776, 281, 4551, 1422, 12, 31498, 518, 7204, 10896, 11172, 433, 11, 50898]),
#  TranscriptionSegment(id=92, avg_logprob=-0.18104338645935059, compression_ratio=1.6188925504684448, end=216.16000366210938, no_speech_prob=0.013424932956695557, seek=20268, start=213.36000061035156, temperature=0.0, text=' has emerged as a vital financing mechanism.', tokens=[50898, 575, 20178, 382, 257, 11707, 22286, 7513, 13, 51038]),
#  TranscriptionSegment(id=93, avg_logprob=-0.18104338645935059, compression_ratio=1.6188925504684448, end=218.60000610351562, no_speech_prob=0.013424932956695557, seek=20268, start=216.16000366210938, temperature=0.0, text=' Its appeal lies in the ability to provide speed', tokens=[51038, 6953, 13668, 9134, 294, 264, 3485, 281, 2893, 3073, 51160]),
#  TranscriptionSegment(id=94, avg_logprob=-0.18104338645935059, compression_ratio=1.6188925504684448, end=221.72000122070312, no_speech_prob=0.013424932956695557, seek=20268, start=218.60000610351562, temperature=0.0, text=' and certainty in execution, term flexibility,', tokens=[51160, 293, 27022, 294, 15058, 11, 1433, 12635, 11, 51316]),
#  TranscriptionSegment(id=95, avg_logprob=-0.18104338645935059, compression_ratio=1.6188925504684448, end=223.8800048828125, no_speech_prob=0.013424932956695557, seek=20268, start=221.72000122070312, temperature=0.0, text=' and closer relationships with borrowers,', tokens=[51316, 293, 4966, 6159, 365, 11172, 433, 11, 51424]),
#  TranscriptionSegment(id=96, avg_logprob=-0.18104338645935059, compression_ratio=1.6188925504684448, end=225.1199951171875, no_speech_prob=0.013424932956695557, seek=20268, start=223.8800048828125, temperature=0.0, text=' an essential toolkit', tokens=[51424, 364, 7115, 40167, 51486]),
#  TranscriptionSegment(id=97, avg_logprob=-0.18104338645935059, compression_ratio=1.6188925504684448, end=227.67999267578125, no_speech_prob=0.013424932956695557, seek=20268, start=225.1199951171875, temperature=0.0, text=' in a competitive financing environment.', tokens=[51486, 294, 257, 10043, 22286, 2823, 13, 51614]),
#  TranscriptionSegment(id=98, avg_logprob=-0.18104338645935059, compression_ratio=1.6188925504684448, end=230.24000549316406, no_speech_prob=0.013424932956695557, seek=20268, start=227.67999267578125, temperature=0.0, text=' Moreover, private credit has become a linchpin', tokens=[51614, 19838, 11, 4551, 5397, 575, 1813, 257, 287, 12415, 17836, 51742]),
#  TranscriptionSegment(id=99, avg_logprob=-0.18104338645935059, compression_ratio=1.6188925504684448, end=231.63999938964844, no_speech_prob=0.013424932956695557, seek=20268, start=230.24000549316406, temperature=0.0, text=' for leveraged buyouts,', tokens=[51742, 337, 12451, 2980, 2256, 7711, 11, 51812]),
#  TranscriptionSegment(id=100, avg_logprob=-0.16553442180156708, compression_ratio=1.5619335174560547, end=234.72000122070312, no_speech_prob=0.004006479866802692, seek=23164, start=231.63999938964844, temperature=0.0, text=' financing approximately 80% of LBOs by count', tokens=[50364, 22286, 10447, 4688, 4, 295, 441, 15893, 82, 538, 1207, 50518]),
#  TranscriptionSegment(id=101, avg_logprob=-0.16553442180156708, compression_ratio=1.5619335174560547, end=237.9199981689453, no_speech_prob=0.004006479866802692, seek=23164, start=234.72000122070312, temperature=0.0, text=' and 50% by volume in Q3 2024.', tokens=[50518, 293, 2625, 4, 538, 5523, 294, 1249, 18, 45237, 13, 50678]),
#  TranscriptionSegment(id=102, avg_logprob=-0.16553442180156708, compression_ratio=1.5619335174560547, end=239.55999755859375, no_speech_prob=0.004006479866802692, seek=23164, start=237.9199981689453, temperature=0.0, text=' This underscores its integral role', tokens=[50678, 639, 16692, 66, 2706, 1080, 11573, 3090, 50760]),
#  TranscriptionSegment(id=103, avg_logprob=-0.16553442180156708, compression_ratio=1.5619335174560547, end=241.63999938964844, no_speech_prob=0.004006479866802692, seek=23164, start=239.55999755859375, temperature=0.0, text=' in facilitating corporate transactions', tokens=[50760, 294, 47558, 10896, 16856, 50864]),
#  TranscriptionSegment(id=104, avg_logprob=-0.16553442180156708, compression_ratio=1.5619335174560547, end=243.36000061035156, no_speech_prob=0.004006479866802692, seek=23164, start=241.63999938964844, temperature=0.0, text=' and fueling business growth.', tokens=[50864, 293, 6616, 278, 1606, 4599, 13, 50950]),
#  TranscriptionSegment(id=105, avg_logprob=-0.16553442180156708, compression_ratio=1.5619335174560547, end=244.9600067138672, no_speech_prob=0.004006479866802692, seek=23164, start=243.36000061035156, temperature=0.0, text=' As we ponder these insights,', tokens=[50950, 1018, 321, 280, 8548, 613, 14310, 11, 51030]),
#  TranscriptionSegment(id=106, avg_logprob=-0.16553442180156708, compression_ratio=1.5619335174560547, end=246.9199981689453, no_speech_prob=0.004006479866802692, seek=23164, start=244.9600067138672, temperature=0.0, text=' let us consider the evolving borrower profiles', tokens=[51030, 718, 505, 1949, 264, 21085, 14828, 81, 968, 23693, 51128]),
#  TranscriptionSegment(id=107, avg_logprob=-0.16553442180156708, compression_ratio=1.5619335174560547, end=248.75999450683594, no_speech_prob=0.004006479866802692, seek=23164, start=246.9199981689453, temperature=0.0, text=' within the private credit space.', tokens=[51128, 1951, 264, 4551, 5397, 1901, 13, 51220]),
#  TranscriptionSegment(id=108, avg_logprob=-0.16553442180156708, compression_ratio=1.5619335174560547, end=251.63999938964844, no_speech_prob=0.004006479866802692, seek=23164, start=248.75999450683594, temperature=0.0, text=' These borrowers, akin to single B or CCC profiles', tokens=[51220, 1981, 11172, 433, 11, 47540, 281, 2167, 363, 420, 383, 11717, 23693, 51364]),
#  TranscriptionSegment(id=109, avg_logprob=-0.16553442180156708, compression_ratio=1.5619335174560547, end=252.67999267578125, no_speech_prob=0.004006479866802692, seek=23164, start=251.63999938964844, temperature=0.0, text=' in the public market,', tokens=[51364, 294, 264, 1908, 2142, 11, 51416]),
#  TranscriptionSegment(id=110, avg_logprob=-0.16553442180156708, compression_ratio=1.5619335174560547, end=254.32000732421875, no_speech_prob=0.004006479866802692, seek=23164, start=252.67999267578125, temperature=0.0, text=' typically exhibit average EBITDA', tokens=[51416, 5850, 20487, 4274, 50148, 3927, 7509, 51498]),
#  TranscriptionSegment(id=111, avg_logprob=-0.16553442180156708, compression_ratio=1.5619335174560547, end=256.7200012207031, no_speech_prob=0.004006479866802692, seek=23164, start=254.32000732421875, temperature=0.0, text=' ranging from $30 million to $40 million', tokens=[51498, 25532, 490, 1848, 3446, 2459, 281, 1848, 5254, 2459, 51618]),
#  TranscriptionSegment(id=112, avg_logprob=-0.16553442180156708, compression_ratio=1.5619335174560547, end=259.20001220703125, no_speech_prob=0.004006479866802692, seek=23164, start=256.7200012207031, temperature=0.0, text=' and leverage ratios of 5 to 7X.', tokens=[51618, 293, 13982, 32435, 295, 1025, 281, 1614, 55, 13, 51742]),
#  TranscriptionSegment(id=113, avg_logprob=-0.16553442180156708, compression_ratio=1.5619335174560547, end=261.2799987792969, no_speech_prob=0.004006479866802692, seek=23164, start=259.20001220703125, temperature=0.0, text=' Despite the challenges posed by rising interest rates', tokens=[51742, 11334, 264, 4759, 31399, 538, 11636, 1179, 6846, 51846]),
#  TranscriptionSegment(id=114, avg_logprob=-0.1830601841211319, compression_ratio=1.6786786317825317, end=262.79998779296875, no_speech_prob=0.0038814879953861237, seek=26128, start=261.2799987792969, temperature=0.0, text=' and economic uncertainty,', tokens=[50364, 293, 4836, 15697, 11, 50440]),
#  TranscriptionSegment(id=115, avg_logprob=-0.1830601841211319, compression_ratio=1.6786786317825317, end=265.1600036621094, no_speech_prob=0.0038814879953861237, seek=26128, start=262.79998779296875, temperature=0.0, text=' direct lending fundamentals have shown resilience,', tokens=[50440, 2047, 29823, 29505, 362, 4898, 19980, 11, 50558]),
#  TranscriptionSegment(id=116, avg_logprob=-0.1830601841211319, compression_ratio=1.6786786317825317, end=268.0400085449219, no_speech_prob=0.0038814879953861237, seek=26128, start=265.1600036621094, temperature=0.0, text=' maintaining stable coverage ratios and EBITDA margins.', tokens=[50558, 14916, 8351, 9645, 32435, 293, 50148, 3927, 7509, 30317, 13, 50702]),
#  TranscriptionSegment(id=117, avg_logprob=-0.1830601841211319, compression_ratio=1.6786786317825317, end=270.0400085449219, no_speech_prob=0.0038814879953861237, seek=26128, start=268.0400085449219, temperature=0.0, text=' In conclusion, the landscape of private credit', tokens=[50702, 682, 10063, 11, 264, 9661, 295, 4551, 5397, 50802]),
#  TranscriptionSegment(id=118, avg_logprob=-0.1830601841211319, compression_ratio=1.6786786317825317, end=273.32000732421875, no_speech_prob=0.0038814879953861237, seek=26128, start=270.0400085449219, temperature=0.0, text=' is a dynamic tableau of opportunities and challenges.', tokens=[50802, 307, 257, 8546, 3199, 1459, 295, 4786, 293, 4759, 13, 50966]),
#  TranscriptionSegment(id=119, avg_logprob=-0.1830601841211319, compression_ratio=1.6786786317825317, end=275.2799987792969, no_speech_prob=0.0038814879953861237, seek=26128, start=273.32000732421875, temperature=0.0, text=' The interplay between public and private markets', tokens=[50966, 440, 728, 2858, 1296, 1908, 293, 4551, 8383, 51064]),
#  TranscriptionSegment(id=120, avg_logprob=-0.1830601841211319, compression_ratio=1.6786786317825317, end=277.7200012207031, no_speech_prob=0.0038814879953861237, seek=26128, start=275.2799987792969, temperature=0.0, text=' continues to shape the refinancing landscape', tokens=[51064, 6515, 281, 3909, 264, 44395, 8779, 9661, 51186]),
#  TranscriptionSegment(id=121, avg_logprob=-0.1830601841211319, compression_ratio=1.6786786317825317, end=280.8800048828125, no_speech_prob=0.0038814879953861237, seek=26128, start=277.7200012207031, temperature=0.0, text=' while competition within credit markets remains fierce.', tokens=[51186, 1339, 6211, 1951, 5397, 8383, 7023, 25341, 13, 51344]),
#  TranscriptionSegment(id=122, avg_logprob=-0.1830601841211319, compression_ratio=1.6786786317825317, end=282.0799865722656, no_speech_prob=0.0038814879953861237, seek=26128, start=280.8800048828125, temperature=0.0, text=' As we look to the future,', tokens=[51344, 1018, 321, 574, 281, 264, 2027, 11, 51404]),
#  TranscriptionSegment(id=123, avg_logprob=-0.1830601841211319, compression_ratio=1.6786786317825317, end=284.760009765625, no_speech_prob=0.0038814879953861237, seek=26128, start=282.0799865722656, temperature=0.0, text=' it is imperative for us as scholars and practitioners', tokens=[51404, 309, 307, 32490, 337, 505, 382, 8553, 293, 25742, 51538]),
#  TranscriptionSegment(id=124, avg_logprob=-0.1830601841211319, compression_ratio=1.6786786317825317, end=287.0799865722656, no_speech_prob=0.0038814879953861237, seek=26128, start=284.760009765625, temperature=0.0, text=' to remain vigilant in monitoring these trends', tokens=[51538, 281, 6222, 45737, 294, 11028, 613, 13892, 51654]),
#  TranscriptionSegment(id=125, avg_logprob=-0.1830601841211319, compression_ratio=1.6786786317825317, end=289.0400085449219, no_speech_prob=0.0038814879953861237, seek=26128, start=287.0799865722656, temperature=0.0, text=' for they will undoubtedly influence the strategies', tokens=[51654, 337, 436, 486, 35211, 6503, 264, 9029, 51752]),
#  TranscriptionSegment(id=126, avg_logprob=-0.19053848087787628, compression_ratio=1.7263157367706299, end=291.67999267578125, no_speech_prob=0.2973552644252777, seek=28904, start=289.0400085449219, temperature=0.0, text=' employed by borrowers and lenders alike.', tokens=[50364, 20115, 538, 11172, 433, 293, 287, 16292, 20025, 13, 50496]),
#  TranscriptionSegment(id=127, avg_logprob=-0.19053848087787628, compression_ratio=1.7263157367706299, end=294.0400085449219, no_speech_prob=0.2973552644252777, seek=28904, start=291.67999267578125, temperature=0.0, text=' I invite you to delve deeper into these findings,', tokens=[50496, 286, 7980, 291, 281, 43098, 7731, 666, 613, 16483, 11, 50614]),
#  TranscriptionSegment(id=128, avg_logprob=-0.19053848087787628, compression_ratio=1.7263157367706299, end=297.239990234375, no_speech_prob=0.2973552644252777, seek=28904, start=294.0400085449219, temperature=0.0, text=' exploring the evolving dynamics of credit markets', tokens=[50614, 12736, 264, 21085, 15679, 295, 5397, 8383, 50774]),
#  TranscriptionSegment(id=129, avg_logprob=-0.19053848087787628, compression_ratio=1.7263157367706299, end=298.8800048828125, no_speech_prob=0.2973552644252777, seek=28904, start=297.239990234375, temperature=0.0, text=' and the potential for private credit', tokens=[50774, 293, 264, 3995, 337, 4551, 5397, 50856]),
#  TranscriptionSegment(id=130, avg_logprob=-0.19053848087787628, compression_ratio=1.7263157367706299, end=301.55999755859375, no_speech_prob=0.2973552644252777, seek=28904, start=298.8800048828125, temperature=0.0, text=' to adapt to changing economic conditions.', tokens=[50856, 281, 6231, 281, 4473, 4836, 4487, 13, 50990]),
#  TranscriptionSegment(id=131, avg_logprob=-0.19053848087787628, compression_ratio=1.7263157367706299, end=303.0400085449219, no_speech_prob=0.2973552644252777, seek=28904, start=301.55999755859375, temperature=0.0, text=' Thank you for your attention', tokens=[50990, 1044, 291, 337, 428, 3202, 51064]),
#  TranscriptionSegment(id=132, avg_logprob=-0.19053848087787628, compression_ratio=1.7263157367706299, end=306.6400146484375, no_speech_prob=0.2973552644252777, seek=28904, start=303.0400085449219, temperature=0.0, text=' and I eagerly anticipate our discussion on this vital topic.', tokens=[51064, 293, 286, 18259, 356, 21685, 527, 5017, 322, 341, 11707, 4829, 13, 51244]),
#  TranscriptionSegment(id=133, avg_logprob=-0.19053848087787628, compression_ratio=1.7263157367706299, end=308.760009765625, no_speech_prob=0.2973552644252777, seek=28904, start=306.6400146484375, temperature=0.0, text=' How do the recent trends in refinancing', tokens=[51244, 1012, 360, 264, 5162, 13892, 294, 44395, 8779, 51350]),
#  TranscriptionSegment(id=134, avg_logprob=-0.19053848087787628, compression_ratio=1.7263157367706299, end=310.79998779296875, no_speech_prob=0.2973552644252777, seek=28904, start=308.760009765625, temperature=0.0, text=' between public and private markets', tokens=[51350, 1296, 1908, 293, 4551, 8383, 51452]),
#  TranscriptionSegment(id=135, avg_logprob=-0.19053848087787628, compression_ratio=1.7263157367706299, end=313.2799987792969, no_speech_prob=0.2973552644252777, seek=28904, start=310.79998779296875, temperature=0.0, text=' reflect the broader economic conditions', tokens=[51452, 5031, 264, 13227, 4836, 4487, 51576]),
#  TranscriptionSegment(id=136, avg_logprob=-0.19053848087787628, compression_ratio=1.7263157367706299, end=315.7200012207031, no_speech_prob=0.2973552644252777, seek=28904, start=313.2799987792969, temperature=0.0, text=' and what implications might this have', tokens=[51576, 293, 437, 16602, 1062, 341, 362, 51698]),
#  TranscriptionSegment(id=137, avg_logprob=-0.19053848087787628, compression_ratio=1.7263157367706299, end=317.67999267578125, no_speech_prob=0.2973552644252777, seek=28904, start=315.7200012207031, temperature=0.0, text=' for future borrower behavior?', tokens=[51698, 337, 2027, 14828, 81, 968, 5223, 30, 51796]),
#  TranscriptionSegment(id=138, avg_logprob=-0.1772872507572174, compression_ratio=1.7158671617507935, end=320.5199890136719, no_speech_prob=0.0014299199683591723, seek=31768, start=317.67999267578125, temperature=0.0, text=' Thank you for engaging with such a great question.', tokens=[50364, 1044, 291, 337, 11268, 365, 1270, 257, 869, 1168, 13, 50506]),
#  TranscriptionSegment(id=139, avg_logprob=-0.1772872507572174, compression_ratio=1.7158671617507935, end=322.0400085449219, no_speech_prob=0.0014299199683591723, seek=31768, start=320.5199890136719, temperature=0.0, text=' Recent trends in refinancing', tokens=[50506, 17553, 13892, 294, 44395, 8779, 50582]),
#  TranscriptionSegment(id=140, avg_logprob=-0.1772872507572174, compression_ratio=1.7158671617507935, end=323.8800048828125, no_speech_prob=0.0014299199683591723, seek=31768, start=322.0400085449219, temperature=0.0, text=' between public and private markets', tokens=[50582, 1296, 1908, 293, 4551, 8383, 50674]),
#  TranscriptionSegment(id=141, avg_logprob=-0.1772872507572174, compression_ratio=1.7158671617507935, end=326.239990234375, no_speech_prob=0.0014299199683591723, seek=31768, start=323.8800048828125, temperature=0.0, text=' mirror broader economic conditions,', tokens=[50674, 8013, 13227, 4836, 4487, 11, 50792]),
#  TranscriptionSegment(id=142, avg_logprob=-0.1772872507572174, compression_ratio=1.7158671617507935, end=328.239990234375, no_speech_prob=0.0014299199683591723, seek=31768, start=326.239990234375, temperature=0.0, text=' highlighting a dual approach.', tokens=[50792, 26551, 257, 11848, 3109, 13, 50892]),
#  TranscriptionSegment(id=143, avg_logprob=-0.1772872507572174, compression_ratio=1.7158671617507935, end=330.2799987792969, no_speech_prob=0.0014299199683591723, seek=31768, start=328.239990234375, temperature=0.0, text=' Borrowers with better credit ratings', tokens=[50892, 363, 3162, 433, 365, 1101, 5397, 24603, 50994]),
#  TranscriptionSegment(id=144, avg_logprob=-0.1772872507572174, compression_ratio=1.7158671617507935, end=333.5199890136719, no_speech_prob=0.0014299199683591723, seek=31768, start=330.2799987792969, temperature=0.0, text=' are drawn to public markets for favorable terms', tokens=[50994, 366, 10117, 281, 1908, 8383, 337, 29557, 2115, 51156]),
# ...
#  TranscriptionSegment(id=203, avg_logprob=-0.18407346308231354, compression_ratio=1.725165605545044, end=475.9599914550781, no_speech_prob=0.00884534977376461, seek=46276, start=473.1600036621094, temperature=0.0, text=' What role do equity injections from sponsors play', tokens=[50884, 708, 3090, 360, 10769, 47178, 490, 22593, 862, 51024]),
#  TranscriptionSegment(id=204, avg_logprob=-0.18407346308231354, compression_ratio=1.725165605545044, end=477.20001220703125, no_speech_prob=0.00884534977376461, seek=46276, start=475.9599914550781, temperature=0.0, text=' in the default landscape?', tokens=[51024, 294, 264, 7576, 9661, 30, 51086]),
#  TranscriptionSegment(id=205, avg_logprob=-0.18407346308231354, compression_ratio=1.725165605545044, end=478.4800109863281, no_speech_prob=0.00884534977376461, seek=46276, start=477.20001220703125, temperature=0.0, text=' And how might this practice evolve', tokens=[51086, 400, 577, 1062, 341, 3124, 16693, 51150]),
#  TranscriptionSegment(id=206, avg_logprob=-0.18407346308231354, compression_ratio=1.725165605545044, end=480.8800048828125, no_speech_prob=0.00884534977376461, seek=46276, start=478.4800109863281, temperature=0.0, text=' as market conditions continue to fluctuate?', tokens=[51150, 382, 2142, 4487, 2354, 281, 23448, 10107, 30, 51270]),
#  TranscriptionSegment(id=207, avg_logprob=-0.18407346308231354, compression_ratio=1.725165605545044, end=482.3599853515625, no_speech_prob=0.00884534977376461, seek=46276, start=480.8800048828125, temperature=0.0, text=' Thank you for your curiosity.', tokens=[51270, 1044, 291, 337, 428, 18769, 13, 51344]),
#  TranscriptionSegment(id=208, avg_logprob=-0.18407346308231354, compression_ratio=1.725165605545044, end=485.9599914550781, no_speech_prob=0.00884534977376461, seek=46276, start=483.2799987792969, temperature=0.0, text=' Equity injections from sponsors play a crucial role', tokens=[51390, 47675, 47178, 490, 22593, 862, 257, 11462, 3090, 51524]),
#  TranscriptionSegment(id=209, avg_logprob=-0.18407346308231354, compression_ratio=1.725165605545044, end=487.8399963378906, no_speech_prob=0.00884534977376461, seek=46276, start=485.9599914550781, temperature=0.0, text=' in stabilizing distressed companies', tokens=[51524, 294, 11652, 3319, 1483, 3805, 3431, 51618]),
#  TranscriptionSegment(id=210, avg_logprob=-0.18407346308231354, compression_ratio=1.725165605545044, end=489.7200012207031, no_speech_prob=0.00884534977376461, seek=46276, start=487.8399963378906, temperature=0.0, text=' within the default landscape.', tokens=[51618, 1951, 264, 7576, 9661, 13, 51712]),
#  TranscriptionSegment(id=211, avg_logprob=-0.18407346308231354, compression_ratio=1.725165605545044, end=492.0400085449219, no_speech_prob=0.00884534977376461, seek=46276, start=489.7200012207031, temperature=0.0, text=' They act as a lifeline, providing liquidity', tokens=[51712, 814, 605, 382, 257, 4545, 5440, 11, 6530, 33131, 51828]),
#  TranscriptionSegment(id=212, avg_logprob=-0.15967300534248352, compression_ratio=1.6845637559890747, end=494.8800048828125, no_speech_prob=0.0016482053324580193, seek=49204, start=492.0799865722656, temperature=0.0, text=' and preserving value during financial stress.', tokens=[50366, 293, 33173, 2158, 1830, 4669, 4244, 13, 50506]),
#  TranscriptionSegment(id=213, avg_logprob=-0.15967300534248352, compression_ratio=1.6845637559890747, end=496.7200012207031, no_speech_prob=0.0016482053324580193, seek=49204, start=494.8800048828125, temperature=0.0, text=' As market conditions fluctuate,', tokens=[50506, 1018, 2142, 4487, 23448, 10107, 11, 50598]),
#  TranscriptionSegment(id=214, avg_logprob=-0.15967300534248352, compression_ratio=1.6845637559890747, end=498.0799865722656, no_speech_prob=0.0016482053324580193, seek=49204, start=496.7200012207031, temperature=0.0, text=' this practice may evolve', tokens=[50598, 341, 3124, 815, 16693, 50666]),
#  TranscriptionSegment(id=215, avg_logprob=-0.15967300534248352, compression_ratio=1.6845637559890747, end=500.0400085449219, no_speech_prob=0.0016482053324580193, seek=49204, start=498.0799865722656, temperature=0.0, text=' with sponsors becoming more selective', tokens=[50666, 365, 22593, 5617, 544, 33930, 50764]),
#  TranscriptionSegment(id=216, avg_logprob=-0.15967300534248352, compression_ratio=1.6845637559890747, end=502.3999938964844, no_speech_prob=0.0016482053324580193, seek=49204, start=500.0400085449219, temperature=0.0, text=' and strategic in their interventions.', tokens=[50764, 293, 10924, 294, 641, 20924, 13, 50882]),
#  TranscriptionSegment(id=217, avg_logprob=-0.15967300534248352, compression_ratio=1.6845637559890747, end=504.6000061035156, no_speech_prob=0.0016482053324580193, seek=49204, start=502.3999938964844, temperature=0.0, text=' The adaptability of private credit markets', tokens=[50882, 440, 6231, 2310, 295, 4551, 5397, 8383, 50992]),
#  TranscriptionSegment(id=218, avg_logprob=-0.15967300534248352, compression_ratio=1.6845637559890747, end=506.20001220703125, no_speech_prob=0.0016482053324580193, seek=49204, start=504.6000061035156, temperature=0.0, text=' to these changes will be key,', tokens=[50992, 281, 613, 2962, 486, 312, 2141, 11, 51072]),
#  TranscriptionSegment(id=219, avg_logprob=-0.15967300534248352, compression_ratio=1.6845637559890747, end=509.9599914550781, no_speech_prob=0.0016482053324580193, seek=49204, start=506.20001220703125, temperature=0.0, text=' potentially leading to more innovative financing solutions.', tokens=[51072, 7263, 5775, 281, 544, 12999, 22286, 6547, 13, 51260]),
#  TranscriptionSegment(id=220, avg_logprob=-0.15967300534248352, compression_ratio=1.6845637559890747, end=511.67999267578125, no_speech_prob=0.0016482053324580193, seek=49204, start=509.9599914550781, temperature=0.0, text=' I encourage further exploration', tokens=[51260, 286, 5373, 3052, 16197, 51346]),
#  TranscriptionSegment(id=221, avg_logprob=-0.15967300534248352, compression_ratio=1.6845637559890747, end=514.239990234375, no_speech_prob=0.0016482053324580193, seek=49204, start=511.67999267578125, temperature=0.0, text=' of how these dynamics will shape the future', tokens=[51346, 295, 577, 613, 15679, 486, 3909, 264, 2027, 51474]),
#  TranscriptionSegment(id=222, avg_logprob=-0.15967300534248352, compression_ratio=1.6845637559890747, end=517.9199829101562, no_speech_prob=0.0016482053324580193, seek=49204, start=514.239990234375, temperature=0.0, text=' of private credit and its impact on borrowers and lenders.', tokens=[51474, 295, 4551, 5397, 293, 1080, 2712, 322, 11172, 433, 293, 287, 16292, 13, 51658]),
#  TranscriptionSegment(id=223, avg_logprob=-0.15967300534248352, compression_ratio=1.6845637559890747, end=520.52001953125, no_speech_prob=0.0016482053324580193, seek=49204, start=517.9199829101562, temperature=0.0, text=" Feel free to ask if there's anything else on your mind.", tokens=[51658, 14113, 1737, 281, 1029, 498, 456, 311, 1340, 1646, 322, 428, 1575, 13, 51788]),
#  TranscriptionSegment(id=224, avg_logprob=-0.1822117567062378, compression_ratio=1.789285659790039, end=522.6799926757812, no_speech_prob=0.00793487299233675, seek=52052, start=520.52001953125, temperature=0.0, text=' As private credit continues to grow,', tokens=[50364, 1018, 4551, 5397, 6515, 281, 1852, 11, 50472]),
#  TranscriptionSegment(id=225, avg_logprob=-0.1822117567062378, compression_ratio=1.789285659790039, end=525.239990234375, no_speech_prob=0.00793487299233675, seek=52052, start=522.6799926757812, temperature=0.0, text=' what potential regulatory challenges could arise', tokens=[50472, 437, 3995, 18260, 4759, 727, 20288, 50600]),
#  TranscriptionSegment(id=226, avg_logprob=-0.1822117567062378, compression_ratio=1.789285659790039, end=527.3200073242188, no_speech_prob=0.00793487299233675, seek=52052, start=525.239990234375, temperature=0.0, text=' and how might these impact the strategies', tokens=[50600, 293, 577, 1062, 613, 2712, 264, 9029, 50704]),
#  TranscriptionSegment(id=227, avg_logprob=-0.1822117567062378, compression_ratio=1.789285659790039, end=528.6400146484375, no_speech_prob=0.00793487299233675, seek=52052, start=527.3200073242188, temperature=0.0, text=' of private debt funds', tokens=[50704, 295, 4551, 7831, 8271, 50770]),
#  TranscriptionSegment(id=228, avg_logprob=-0.1822117567062378, compression_ratio=1.789285659790039, end=530.9600219726562, no_speech_prob=0.00793487299233675, seek=52052, start=528.6400146484375, temperature=0.0, text=' and their relationships with borrowers?', tokens=[50770, 293, 641, 6159, 365, 11172, 433, 30, 50886]),
#  TranscriptionSegment(id=229, avg_logprob=-0.1822117567062378, compression_ratio=1.789285659790039, end=532.5599975585938, no_speech_prob=0.00793487299233675, seek=52052, start=530.9600219726562, temperature=0.0, text=" I'm glad you asked.", tokens=[50886, 286, 478, 5404, 291, 2351, 13, 50966]),
#  TranscriptionSegment(id=230, avg_logprob=-0.1822117567062378, compression_ratio=1.789285659790039, end=534.0399780273438, no_speech_prob=0.00793487299233675, seek=52052, start=532.5599975585938, temperature=0.0, text=' As private credit grows,', tokens=[50966, 1018, 4551, 5397, 13156, 11, 51040]),
#  TranscriptionSegment(id=231, avg_logprob=-0.1822117567062378, compression_ratio=1.789285659790039, end=536.8800048828125, no_speech_prob=0.00793487299233675, seek=52052, start=534.0399780273438, temperature=0.0, text=' regulatory challenges may include increased scrutiny', tokens=[51040, 18260, 4759, 815, 4090, 6505, 38615, 51182]),
#  TranscriptionSegment(id=232, avg_logprob=-0.1822117567062378, compression_ratio=1.789285659790039, end=541.47998046875, no_speech_prob=0.00793487299233675, seek=52052, start=536.8800048828125, temperature=0.0, text=' on transparency, risk management and borrower protections.', tokens=[51182, 322, 17131, 11, 3148, 4592, 293, 14828, 81, 968, 29031, 13, 51412]),
#  TranscriptionSegment(id=233, avg_logprob=-0.1822117567062378, compression_ratio=1.789285659790039, end=543.1599731445312, no_speech_prob=0.00793487299233675, seek=52052, start=541.47998046875, temperature=0.0, text=' These could impact private debt funds', tokens=[51412, 1981, 727, 2712, 4551, 7831, 8271, 51496]),
#  TranscriptionSegment(id=234, avg_logprob=-0.1822117567062378, compression_ratio=1.789285659790039, end=545.719970703125, no_speech_prob=0.00793487299233675, seek=52052, start=543.1599731445312, temperature=0.0, text=' by necessitating stricter compliance measures', tokens=[51496, 538, 2688, 16350, 1056, 299, 391, 15882, 8000, 51624]),
#  TranscriptionSegment(id=235, avg_logprob=-0.1822117567062378, compression_ratio=1.789285659790039, end=547.6799926757812, no_speech_prob=0.00793487299233675, seek=52052, start=545.719970703125, temperature=0.0, text=' and potentially altering loan structures', tokens=[51624, 293, 7263, 11337, 278, 10529, 9227, 51722]),
#  TranscriptionSegment(id=236, avg_logprob=-0.1822117567062378, compression_ratio=1.789285659790039, end=549.6400146484375, no_speech_prob=0.00793487299233675, seek=52052, start=547.6799926757812, temperature=0.0, text=' to meet regulatory standards.', tokens=[51722, 281, 1677, 18260, 7787, 13, 51820]),
#  TranscriptionSegment(id=237, avg_logprob=-0.17277204990386963, compression_ratio=1.6338461637496948, end=551.0, no_speech_prob=0.00013340250006876886, seek=54964, start=549.6400146484375, temperature=0.0, text=' The relationship with borrowers', tokens=[50364, 440, 2480, 365, 11172, 433, 50432]),
#  TranscriptionSegment(id=238, avg_logprob=-0.17277204990386963, compression_ratio=1.6338461637496948, end=553.5999755859375, no_speech_prob=0.00013340250006876886, seek=54964, start=551.0, temperature=0.0, text=' might shift towards more formalized agreements,', tokens=[50432, 1062, 5513, 3030, 544, 9860, 1602, 21422, 11, 50562]),
#  TranscriptionSegment(id=239, avg_logprob=-0.17277204990386963, compression_ratio=1.6338461637496948, end=555.8800048828125, no_speech_prob=0.00013340250006876886, seek=54964, start=553.5999755859375, temperature=0.0, text=' impacting the flexibility and speed', tokens=[50562, 29963, 264, 12635, 293, 3073, 50676]),
#  TranscriptionSegment(id=240, avg_logprob=-0.17277204990386963, compression_ratio=1.6338461637496948, end=557.8800048828125, no_speech_prob=0.00013340250006876886, seek=54964, start=555.8800048828125, temperature=0.0, text=' that currently characterize private credit.', tokens=[50676, 300, 4362, 38463, 4551, 5397, 13, 50776]),
#  TranscriptionSegment(id=241, avg_logprob=-0.17277204990386963, compression_ratio=1.6338461637496948, end=560.6799926757812, no_speech_prob=0.00013340250006876886, seek=54964, start=557.8800048828125, temperature=0.0, text=' This evolving landscape invites further exploration', tokens=[50776, 639, 21085, 9661, 35719, 3052, 16197, 50916]),
#  TranscriptionSegment(id=242, avg_logprob=-0.17277204990386963, compression_ratio=1.6338461637496948, end=562.3200073242188, no_speech_prob=0.00013340250006876886, seek=54964, start=560.6799926757812, temperature=0.0, text=' of how regulatory frameworks', tokens=[50916, 295, 577, 18260, 29834, 50998]),
#  TranscriptionSegment(id=243, avg_logprob=-0.17277204990386963, compression_ratio=1.6338461637496948, end=565.1599731445312, no_speech_prob=0.00013340250006876886, seek=54964, start=562.3200073242188, temperature=0.0, text=' can balance market growth with financial stability,', tokens=[50998, 393, 4772, 2142, 4599, 365, 4669, 11826, 11, 51140]),
#  TranscriptionSegment(id=244, avg_logprob=-0.17277204990386963, compression_ratio=1.6338461637496948, end=566.4000244140625, no_speech_prob=0.00013340250006876886, seek=54964, start=565.1599731445312, temperature=0.0, text=' encouraging a dialogue', tokens=[51140, 14580, 257, 10221, 51202]),
#  TranscriptionSegment(id=245, avg_logprob=-0.17277204990386963, compression_ratio=1.6338461637496948, end=569.4400024414062, no_speech_prob=0.00013340250006876886, seek=54964, start=566.4000244140625, temperature=0.0, text=' on the future strategies of private debt funds.', tokens=[51202, 322, 264, 2027, 9029, 295, 4551, 7831, 8271, 13, 51354]),
#  TranscriptionSegment(id=246, avg_logprob=-0.17277204990386963, compression_ratio=1.6338461637496948, end=571.8400268554688, no_speech_prob=0.00013340250006876886, seek=54964, start=569.4400024414062, temperature=0.0, text=' Would anyone like to ask anything more?', tokens=[51354, 6068, 2878, 411, 281, 1029, 1340, 544, 30, 51474]),
#  TranscriptionSegment(id=247, avg_logprob=-0.17277204990386963, compression_ratio=1.6338461637496948, end=573.4400024414062, no_speech_prob=0.00013340250006876886, seek=54964, start=571.8400268554688, temperature=0.0, text=' If there are no other questions,', tokens=[51474, 759, 456, 366, 572, 661, 1651, 11, 51554]),
#  TranscriptionSegment(id=248, avg_logprob=-0.17277204990386963, compression_ratio=1.6338461637496948, end=576.6799926757812, no_speech_prob=0.00013340250006876886, seek=54964, start=573.4400024414062, temperature=0.0, text=' I would like to thank the audience for their attention today.', tokens=[51554, 286, 576, 411, 281, 1309, 264, 4034, 337, 641, 3202, 965, 13, 51716]),
#  TranscriptionSegment(id=249, avg_logprob=-0.17277204990386963, compression_ratio=1.6338461637496948, end=578.4000244140625, no_speech_prob=0.00013340250006876886, seek=54964, start=576.6799926757812, temperature=0.0, text=' If you think of questions later,', tokens=[51716, 759, 291, 519, 295, 1651, 1780, 11, 51802]),
#  TranscriptionSegment(id=250, avg_logprob=-0.33622023463249207, compression_ratio=0.9137930870056152, end=580.8400268554688, no_speech_prob=0.002213063882663846, seek=57840, start=578.4000244140625, temperature=0.0, text=' please feel free to send me a note.', tokens=[50364, 1767, 841, 1737, 281, 2845, 385, 257, 3637, 13, 50486]),
#  TranscriptionSegment(id=251, avg_logprob=-0.33622023463249207, compression_ratio=0.9137930870056152, end=581.8400268554688, no_speech_prob=0.002213063882663846, seek=57840, start=580.8400268554688, temperature=0.0, text=' Have a great day.', tokens=[50486, 3560, 257, 869, 786, 13, 50536])]
